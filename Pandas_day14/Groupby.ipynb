# %% [markdown]
# # Groupby

# %%
import numpy as np
import pandas as pd

# %%
## read data from csv file
# file_path = "path.csv"
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
# Mininum price 
df['price'].min()
# Out:
# 4400.0

# %%
# Maxinum price 
df['price'].max()
# Out:
# 1900000.0

# %%
# Mean price 
df['price'].mean()
# Out:
# 68295.41763660868

# %%
df['brand'] == "TVS"
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 32643    False
# 32644     True
# 32645    False
# 32646    False
# 32647    False
# Name: brand, Length: 32648, dtype: bool

# %%
df[df['brand'] == "TVS"]
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
# Minimum price for TVS brand

df[df['brand'] == "TVS"]['price'].min()
# Out:
# 5800.0

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
brand_group = df.groupby('brand')
brand_group

# %%
brand_group.get_group('TVS')
# Out:
#                                 bike_name    price       city  kms_driven  \
# 0      TVS Star City Plus Dual Tone 110cc  35000.0  Ahmedabad     17654.0
# 3                    TVS Apache RTR 180cc  65000.0  Bangalore     16329.0
# 52                   TVS Apache RTR 160cc  60000.0     Mumbai     30000.0
# 114            TVS Apache RTR 160 4V Disc  69900.0      Delhi      8700.0
# 130                TVS Phoenix Disc 125cc  21500.0    Barasat     10500.0
# ...                                   ...      ...        ...         ...
# 32549                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32568                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32587                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32606                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
# 32644                TVS Apache RTR 180cc  30000.0     Karnal      6639.0
#
#              owner  age  power brand
# 0      First Owner  3.0  110.0   TVS
# ...

# %%
brand_group.get_group('Yamaha')
# Out:
#                                   bike_name     price         city  \
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0    Bangalore
# 5                          Yamaha FZs 150cc   53499.0        Delhi
# 10                 Yamaha YZF-R15 2.0 150cc   72000.0    Bangalore
# 11                        Yamaha FZ25 250cc   95000.0    Bangalore
# 24                    Yamaha FZ V 2.0 150cc   45000.0        Delhi
# ...                                     ...       ...          ...
# 32610                       Yamaha FZ 150cc   45000.0      Chennai
# 32612              Yamaha YZF-R15 2.0 150cc   55000.0     Rupnagar
# 32622                    Yamaha Fazer 150cc   25000.0        Delhi
# 32631                    Yamaha SZ-RR 150cc   20000.0  Kanchipuram
# 32638                 Yamaha Fazer 25 250cc  123000.0       Kadapa
#
#        kms_driven        owner   age  power   brand
# 4         10000.0  First Owner   3.0  150.0  Yamaha
# 5         25000.0  First Owner   6.0  150.0  Yamaha
# ...

# %%
brand_group[['price']].min()
# Out:
#                     price
# brand
# BMW              255000.0
# Bajaj              6400.0
# Benelli          110700.0
# Ducati           380000.0
# Harley-Davidson  250000.0
# Hero               5000.0
# Honda             10000.0
# Hyosung          120000.0
# Ideal            100000.0
# Indian           700000.0
# Jawa             146000.0
# KTM               55000.0
# Kawasaki         110000.0
# LML                4400.0
# MV               950000.0
# Mahindra          17800.0
# Rajdoot           75000.0
# Royal Enfield     33500.0
# Suzuki             8000.0
# TVS                5800.0
# Triumph          500000.0
# Yamaha             9400.0
# Yezdi             68000.0

# %%
brand_group[['price']].max()
# Out:
#                      price
# brand
# BMW              1800000.0
# Bajaj             195000.0
# Benelli           785000.0
# Ducati           1500000.0
# Harley-Davidson  1100000.0
# Hero              104000.0
# Honda             800000.0
# Hyosung           493500.0
# Ideal             100000.0
# Indian           1900000.0
# Jawa              223000.0
# KTM               860000.0
# Kawasaki         1100000.0
# LML                 4400.0
# MV               1500000.0
# Mahindra          175000.0
# Rajdoot            75000.0
# Royal Enfield     285000.0
# Suzuki           1260000.0
# TVS               224000.0
# Triumph          1300000.0
# Yamaha           1550000.0
# Yezdi              68000.0

# %%
brand_group[['price']].mean()
# Out:
#                         price
# brand
# BMW              5.987500e+05
# Bajaj            4.833127e+04
# Benelli          2.942000e+05
# Ducati           9.355455e+05
# Harley-Davidson  4.529988e+05
# Hero             2.382945e+04
# Honda            5.923047e+04
# Hyosung          2.491678e+05
# Ideal            1.000000e+05
# Indian           1.100000e+06
# Jawa             1.855000e+05
# KTM              1.746697e+05
# Kawasaki         4.116246e+05
# LML              4.400000e+03
# MV               1.325000e+06
# Mahindra         7.250709e+04
# Rajdoot          7.500000e+04
# Royal Enfield    9.856207e+04
# Suzuki           4.594683e+04
# TVS              4.429915e+04
# Triumph          8.274230e+05
# Yamaha           5.706896e+04
# Yezdi            6.800000e+04

# %%
brand_group['price'].agg(min_price='min',max_price='max',avg_price='mean')
# Out:
#                  min_price  max_price     avg_price
# brand
# BMW               255000.0  1800000.0  5.987500e+05
# Bajaj               6400.0   195000.0  4.833127e+04
# Benelli           110700.0   785000.0  2.942000e+05
# Ducati            380000.0  1500000.0  9.355455e+05
# Harley-Davidson   250000.0  1100000.0  4.529988e+05
# Hero                5000.0   104000.0  2.382945e+04
# Honda              10000.0   800000.0  5.923047e+04
# Hyosung           120000.0   493500.0  2.491678e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.855000e+05
# KTM                55000.0   860000.0  1.746697e+05
# Kawasaki          110000.0  1100000.0  4.116246e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.325000e+06
# Mahindra           17800.0   175000.0  7.250709e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
brand_group['kms_driven'].agg(min_price='min',max_price='max',avg_price='mean')
# Out:
#                  min_price  max_price     avg_price
# brand
# BMW                 2200.0    18000.0   8614.687500
# Bajaj                 22.0   717794.0  29711.079818
# Benelli             1000.0    27000.0  12499.517857
# Ducati                 3.0    31000.0   7224.909091
# Harley-Davidson      200.0    63000.0   4459.084125
# Hero                   1.0   750000.0  31977.075377
# Honda                 68.0   654984.0  24034.615750
# Hyosung              210.0    51791.0   8891.859375
# Ideal              80000.0    80000.0  80000.000000
# Indian               172.0     1700.0    681.666667
# Jawa                 381.0     2388.0   1396.000000
# KTM                   40.0   100000.0  14006.932219
# Kawasaki             180.0    36102.0   9538.848101
# LML                55000.0    55000.0  55000.000000
# MV                  1911.0     6898.0   3202.250000
# Mahindra            1400.0    55000.0  21112.690909
# Rajdoot              500.0      500.0    500.000000
# ...

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
group_brand = df['owner'].value_counts()
group_brand
# Out:
# owner
# First Owner             29964
# Second Owner             2564
# Third Owner               108
# Fourth Owner Or More       12
# Name: count, dtype: int64

# %%
df['brand'] == "owner"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32643    False
# 32644    False
# 32645    False
# 32646    False
# 32647    False
# Name: brand, Length: 32648, dtype: bool

# %%
brand_group['price'].agg(min_price='min',max_price='max',avg_price='mean')
# Out:
#                  min_price  max_price     avg_price
# brand
# BMW               255000.0  1800000.0  5.987500e+05
# Bajaj               6400.0   195000.0  4.833127e+04
# Benelli           110700.0   785000.0  2.942000e+05
# Ducati            380000.0  1500000.0  9.355455e+05
# Harley-Davidson   250000.0  1100000.0  4.529988e+05
# Hero                5000.0   104000.0  2.382945e+04
# Honda              10000.0   800000.0  5.923047e+04
# Hyosung           120000.0   493500.0  2.491678e+05
# Ideal             100000.0   100000.0  1.000000e+05
# Indian            700000.0  1900000.0  1.100000e+06
# Jawa              146000.0   223000.0  1.855000e+05
# KTM                55000.0   860000.0  1.746697e+05
# Kawasaki          110000.0  1100000.0  4.116246e+05
# LML                 4400.0     4400.0  4.400000e+03
# MV                950000.0  1500000.0  1.325000e+06
# Mahindra           17800.0   175000.0  7.250709e+04
# Rajdoot            75000.0    75000.0  7.500000e+04
# ...

# %%
# num_col = df.select_dtypes(exclude='0')
# num_col.head()

# %%
# df = pd.concat([cat_col,num_col],axis='columns')
# df.head()

# %%
# Merge()  = mergesort for joints
