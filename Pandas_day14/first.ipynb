# %% [markdown]
# # Pandas

# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# Pandas are used for folling :-
# 1. Data Analyse
# 2. Data Manipulation
# 3. Data Transform
# 4. Data Cleaning
# 5. Data Preprocessing
# 6. Filtering
# 7. Searching, Sorting , Grouping

# %% [markdown]
# It also read data from excel , json , mysql etc. and in different type of data

# %% [markdown]
# Dataframe  ==>  pandas primary tabular data structures
#
# It handle structure data and Tabuar data such as spreadsheet or SQL tables , csv files etc .

# %% [markdown]
# Series ==> A Series is a 1-dimensional labeled array ecpable of holding any data types eg:-  integers, strings, floats etc.

# %%
## What is dataframe 
## How we create dataframe , array , list , dictionary

# %%
dict = {"Name":["Ritu","Taniya","abhishek","tanmay","mayank"],
        "Branch":['it','cse','it','ece','cse'],
        "Class":[2,3,4,1,2],
        "City":['jaipue','agra','vridavan','mathura','gokul']}

# %%
dict
# Out:
# {'Name': ['Ritu', 'Taniya', 'abhishek', 'tanmay', 'mayank'],
#  'Branch': ['it', 'cse', 'it', 'ece', 'cse'],
#  'Class': [2, 3, 4, 1, 2],
#  'City': ['jaipue', 'agra', 'vridavan', 'mathura', 'gokul']}

# %%
np.array(dict)
# Out:
# array({'Name': ['Ritu', 'Taniya', 'abhishek', 'tanmay', 'mayank'], 'Branch': ['it', 'cse', 'it', 'ece', 'cse'], 'Class': [2, 3, 4, 1, 2], 'City': ['jaipue', 'agra', 'vridavan', 'mathura', 'gokul']},
#       dtype=object)

# %%
pd.DataFrame(dict)
# Out:
#        Name Branch  Class      City
# 0      Ritu     it      2    jaipue
# 1    Taniya    cse      3      agra
# 2  abhishek     it      4  vridavan
# 3    tanmay    ece      1   mathura
# 4    mayank    cse      2     gokul

# %%
df = pd.DataFrame(dict)
df
# Out:
#        Name Branch  Class      City
# 0      Ritu     it      2    jaipue
# 1    Taniya    cse      3      agra
# 2  abhishek     it      4  vridavan
# 3    tanmay    ece      1   mathura
# 4    mayank    cse      2     gokul

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
## <<<<<<<< Series >>>>>>>>---->>>

# %%
df['Name']
# Out:
# 0        Ritu
# 1      Taniya
# 2    abhishek
# 3      tanmay
# 4      mayank
# Name: Name, dtype: object

# %%
df.Name
# Out:
# 0        Ritu
# 1      Taniya
# 2    abhishek
# 3      tanmay
# 4      mayank
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Class']
# Out:
# 0    2
# 1    3
# 2    4
# 3    1
# 4    2
# Name: Class, dtype: int64

# %%
# Object == String == categorical
df.dtypes
# Out:
# Name      object
# Branch    object
# Class      int64
# City      object
# dtype: object

# %%
df.shape  # 5 rows and 4 column
# Out:
# (5, 4)

# %%
df
# Out:
#        Name Branch  Class      City
# 0      Ritu     it      2    jaipue
# 1    Taniya    cse      3      agra
# 2  abhishek     it      4  vridavan
# 3    tanmay    ece      1   mathura
# 4    mayank    cse      2     gokul

# %%
df[['City','Name','Branch']]  #  For multiple columns
# Out:
#        City      Name Branch
# 0    jaipue      Ritu     it
# 1      agra    Taniya    cse
# 2  vridavan  abhishek     it
# 3   mathura    tanmay    ece
# 4     gokul    mayank    cse

# %%
df[['Class','Branch']]
# Out:
#    Class Branch
# 0      2     it
# 1      3    cse
# 2      4     it
# 3      1    ece
# 4      2    cse

# %%
df
# Out:
#        Name Branch  Class      City
# 0      Ritu     it      2    jaipue
# 1    Taniya    cse      3      agra
# 2  abhishek     it      4  vridavan
# 3    tanmay    ece      1   mathura
# 4    mayank    cse      2     gokul

# %%
df[1:3]
# Out:
#        Name Branch  Class      City
# 1    Taniya    cse      3      agra
# 2  abhishek     it      4  vridavan

# %%
df[1:2]
# Out:
#      Name Branch  Class  City
# 1  Taniya    cse      3  agra

# %%
df[['Name','Branch']][1:3][0:2]
# Out:
#        Name Branch
# 1    Taniya    cse
# 2  abhishek     it

# %%
# LOC or ILOC 

# LOC ==> stoping point inclusive hota h
df.loc[1:2,['Name','Branch']]
# Out:
#        Name Branch
# 1    Taniya    cse
# 2  abhishek     it

# %%
df.loc[3:4,['Branch','Class','City']]
# Out:
#   Branch  Class     City
# 3    ece      1  mathura
# 4    cse      2    gokul

# %%
# ILOC
# ILOC ==> stoping point not inclusive hota h
df.iloc[1:3,0:2]
# Out:
#        Name Branch
# 1    Taniya    cse
# 2  abhishek     it

# %%
df.iloc[3:,1:]
# Out:
#   Branch  Class     City
# 3    ece      1  mathura
# 4    cse      2    gokul

# %% [markdown]
# # Dataset

# %%
## read data from csv file
# file_path = "path.csv"
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %% [markdown]
# # Filtering

# %%
df.head()    # by default top 5 records
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
df.head(10)
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# 5                          Yamaha FZs 150cc   53499.0      Delhi     25000.0
# 6             Honda CB Hornet 160R  ABS DLX   85000.0      Delhi      8200.0
# 7       Hero Splendor Plus Self Alloy 100cc   45000.0      Delhi     12645.0
# 8         Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9  Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
#
#           owner  age  power          brand
# 0   First Owner  3.0  110.0            TVS
# ...

# %%
df.tail(10) # show last 10 rows
# Out:
#                          bike_name     price         city  kms_driven  \
# 32638        Yamaha Fazer 25 250cc  123000.0       Kadapa     14500.0
# 32639  Royal Enfield Classic 350cc   95500.0        Delhi     18000.0
# 32640       Hero Passion Pro 100cc   32000.0        Delhi     12000.0
# 32641          Bajaj Avenger 220cc   41000.0        Delhi     20245.0
# 32642           Hero Passion 100cc   15000.0  Perumbavoor     35000.0
# 32643       Hero Passion Pro 100cc   39000.0        Delhi     22000.0
# 32644         TVS Apache RTR 180cc   30000.0       Karnal      6639.0
# 32645     Bajaj Avenger Street 220   60000.0        Delhi     20373.0
# 32646    Hero Super Splendor 125cc   15600.0       Jaipur     84186.0
# 32647           Bajaj Pulsar 150cc   22000.0         Pune     60857.0
#
#               owner   age  power          brand
# 32638   First Owner   4.0  250.0         Yamaha
# 32639   First Owner   8.0  350.0  Royal Enfield
# 32640   First Owner   6.0  100.0           Hero
# ...

# %%
df['brand']
# Out:
# 0                  TVS
# 1        Royal Enfield
# 2              Triumph
# 3                  TVS
# 4               Yamaha
#              ...
# 32643             Hero
# 32644              TVS
# 32645            Bajaj
# 32646             Hero
# 32647            Bajaj
# Name: brand, Length: 32648, dtype: object

# %%
df['brand'].nunique() # 23 total unique brands are exist
# Out:
# 23

# %%
df['brand'].unique()
# Out:
# array(['TVS', 'Royal Enfield', 'Triumph', 'Yamaha', 'Honda', 'Hero',
#        'Bajaj', 'Suzuki', 'Benelli', 'KTM', 'Mahindra', 'Kawasaki',
#        'Ducati', 'Hyosung', 'Harley-Davidson', 'Jawa', 'BMW', 'Indian',
#        'Rajdoot', 'LML', 'Yezdi', 'MV', 'Ideal'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              11213
# Hero                6368
# Royal Enfield       4178
# Yamaha              3916
# Honda               2108
# Suzuki              1464
# TVS                 1247
# KTM                 1077
# Harley-Davidson      737
# Kawasaki              79
# Hyosung               64
# Benelli               56
# Mahindra              55
# Triumph               26
# Ducati                22
# BMW                   16
# Jawa                  10
# MV                     4
# Indian                 3
# Ideal                  2
# Rajdoot                1
# LML                    1
# Yezdi                  1
# Name: count, dtype: int64

# %%
df['brand'] == "Royal Enfield"
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 32643    False
# 32644    False
# 32645    False
# 32646    False
# 32647    False
# Name: brand, Length: 32648, dtype: bool

# %%
df[df['brand'] == "Royal Enfield"]
# Out:
#                                       bike_name     price  \
# 1                   Royal Enfield Classic 350cc  119900.0
# 8             Royal Enfield Thunderbird X 350cc  145000.0
# 9      Royal Enfield Classic Desert Storm 500cc   88000.0
# 23           Royal Enfield Classic Chrome 500cc  121700.0
# 36                  Royal Enfield Classic 350cc   98800.0
# ...                                         ...       ...
# 32601               Royal Enfield Classic 350cc   95500.0
# 32614        Royal Enfield Bullet Electra 350cc  105000.0
# 32633               Royal Enfield Classic 350cc   87000.0
# 32634           Royal Enfield Thunderbird 350cc   70000.0
# 32639               Royal Enfield Classic 350cc   95500.0
#
#                       city  kms_driven         owner   age  power  \
# 1                    Delhi     11000.0   First Owner   4.0  350.0
# 8                Bangalore      9190.0   First Owner   3.0  350.0
# 9                    Delhi     19000.0  Second Owner   7.0  500.0
# ...

# %%
bullet =df[df['brand'] == "Royal Enfield"] # condition on singel

# %%
bullet.head()
# Out:
#                                    bike_name     price       city  kms_driven  \
# 1                Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 8          Royal Enfield Thunderbird X 350cc  145000.0  Bangalore      9190.0
# 9   Royal Enfield Classic Desert Storm 500cc   88000.0      Delhi     19000.0
# 23        Royal Enfield Classic Chrome 500cc  121700.0     Kalyan     24520.0
# 36               Royal Enfield Classic 350cc   98800.0      Kochi     39000.0
#
#            owner  age  power          brand
# 1    First Owner  4.0  350.0  Royal Enfield
# 8    First Owner  3.0  350.0  Royal Enfield
# 9   Second Owner  7.0  500.0  Royal Enfield
# 23   First Owner  5.0  500.0  Royal Enfield
# 36   First Owner  5.0  350.0  Royal Enfield

# %%
bullet.shape
# Out:
# (4178, 8)

# %%
# brand  = royal enfield
# age == less than 2 years 
# owner == First Owner


# Condition 1  , 2 and 3
df[(df['brand'] == "Royal Enfield")  & (df['age'] <= 2)  &  (df['owner'] == 'First Owner')]
# Out:
#                                    bike_name     price         city  \
# 38         Royal Enfield Thunderbird X 500cc  190500.0   Samastipur
# 81           Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai
# 139     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 157     Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara
# 194              Royal Enfield Electra 350cc  145000.0    Bangalore
# ...                                      ...       ...          ...
# 7694  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 7706  Royal Enfield Classic Chrome 500cc ABS  215000.0        Delhi
# 8139   Royal Enfield Thunderbird X 350cc ABS  169000.0    Bangalore
# 8192     Royal Enfield Thunderbird 350cc ABS  145000.0    Ghaziabad
# 8836   Royal Enfield Thunderbird X 350cc ABS  170200.0       Mumbai
#
#       kms_driven        owner  age  power          brand
# 38        4550.0  First Owner  2.0  500.0  Royal Enfield
# ...

# %%
bullet = df[(df['brand'] == "Royal Enfield")  & (df['age'] <= 2)  &  (df['owner'] == 'First Owner')]

# %%
bullet.head()
# Out:
#                                 bike_name     price         city  kms_driven  \
# 38      Royal Enfield Thunderbird X 500cc  190500.0   Samastipur      4550.0
# 81        Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai      3800.0
# 139  Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara     14000.0
# 157  Royal Enfield Himalayan 410cc Fi ABS  173300.0     Vadodara     14000.0
# 194           Royal Enfield Electra 350cc  145000.0    Bangalore      4000.0
#
#            owner  age  power          brand
# 38   First Owner  2.0  500.0  Royal Enfield
# 81   First Owner  2.0  650.0  Royal Enfield
# 139  First Owner  2.0  410.0  Royal Enfield
# 157  First Owner  2.0  410.0  Royal Enfield
# 194  First Owner  2.0  350.0  Royal Enfield

# %%
bullet.shape
# Out:
# (84, 8)

# %%
bullet['city'].nunique()
# Out:
# 28

# %%
bullet['city'].unique()
# Out:
# array(['Samastipur', 'Navi Mumbai', 'Vadodara', 'Bangalore',
#        'Hamirpur(hp)', 'Mumbai', 'Delhi', 'Guwahati', 'Haldwani',
#        'Ahmedabad', 'Bardhaman', 'Silchar', 'Sibsagar', 'Kharar',
#        'Baripara', 'Sonipat', 'Pune', 'Farukhabad', 'Sultanpur',
#        'Hyderabad', 'Gurgaon', 'Faridabad', 'Kota', 'Thane', 'Nellore',
#        'Alipore', 'Ghaziabad', 'Noida'], dtype=object)

# %%
bullet['city'].value_counts()
# Out:
# city
# Delhi           18
# Mumbai          10
# Bangalore        6
# Ahmedabad        6
# Vadodara         4
# Guwahati         4
# Faridabad        4
# Hyderabad        3
# Ghaziabad        3
# Kharar           2
# Farukhabad       2
# Navi Mumbai      2
# Bardhaman        2
# Sibsagar         2
# Gurgaon          2
# Alipore          2
# Nellore          1
# Thane            1
# Kota             1
# Samastipur       1
# Baripara         1
# Sultanpur        1
# Pune             1
# Sonipat          1
# Silchar          1
# Haldwani         1
# Hamirpur(hp)     1
# Noida            1
# Name: count, dtype: int64

# %%
# City == Jaipur
# age <= 2
# owner == first owner

# %%
df[(df['city'] == "Jaipur")  & (df['age'] <= 2)  &  (df['owner'] == 'First Owner')]
# Out:
#                                bike_name     price    city  kms_driven  \
# 47            Mahindra Centuro NXT 110cc   28000.0  Jaipur     45000.0
# 972                    Yamaha FZ25 250cc  105000.0  Jaipur     10468.0
# 1132  TVS Apache RTR 160 4V DISC ABS BS6   98000.0  Jaipur       749.0
# 1182                   Yamaha FZ25 250cc  105000.0  Jaipur     10468.0
# 2185       Bajaj Platina 110 H Gear Disc   43500.0  Jaipur     18346.0
# 3942                    Honda Livo 110cc   52000.0  Jaipur     12322.0
# 4525                    Honda Livo 110cc   52000.0  Jaipur     12322.0
# 4749                    Honda Livo 110cc   53214.0  Jaipur     15492.0
# 4781                    Honda Livo 110cc   53214.0  Jaipur     15492.0
# 6073                        KTM RC 200cc  190000.0  Jaipur      7902.0
# 6552                        KTM RC 200cc  190000.0  Jaipur      7902.0
# 7311                TVS Apache RTR 180cc   70000.0  Jaipur    207102.0
# ...

# %%
bullet  = df[(df['city'] == "Jaipur")  & (df['age'] <= 2)  &  (df['owner'] == 'First Owner')]

# %%
bullet.head()
# Out:
#                                bike_name     price    city  kms_driven  \
# 47            Mahindra Centuro NXT 110cc   28000.0  Jaipur     45000.0
# 972                    Yamaha FZ25 250cc  105000.0  Jaipur     10468.0
# 1132  TVS Apache RTR 160 4V DISC ABS BS6   98000.0  Jaipur       749.0
# 1182                   Yamaha FZ25 250cc  105000.0  Jaipur     10468.0
# 2185       Bajaj Platina 110 H Gear Disc   43500.0  Jaipur     18346.0
#
#             owner  age  power     brand
# 47    First Owner  2.0  110.0  Mahindra
# 972   First Owner  2.0  250.0    Yamaha
# 1132  First Owner  1.0  160.0       TVS
# 1182  First Owner  2.0  250.0    Yamaha
# 2185  First Owner  2.0  110.0     Bajaj

# %%
bullet.shape
# Out:
# (13, 8)

# %%
bullet['city'].nunique()
# Out:
# 1

# %%
bullet['city'].unique()
# Out:
# array(['Jaipur'], dtype=object)

# %%
bike = df[(df['brand'] == "KTM") & (df['brand'] == "Java")]
bike
# Out:
# Empty DataFrame
# Columns: [bike_name, price, city, kms_driven, owner, age, power, brand]
# Index: []

# %%
bike = df[(df['brand'] == "KTM") | (df['brand'] == "Java")] 
bike
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand
# 33     390.0   KTM
# ...

# %%
bike['brand'].value_counts()
# Out:
# brand
# KTM    1077
# Name: count, dtype: int64

# %%
bike['city'].unique()
# Out:
# array(['Pune', 'Nashik', 'Bangalore', 'Baripara', 'Gandhidham', 'Delhi',
#        'Navi Mumbai', 'Amritsar', 'Mumbai', 'Kottayam', 'Bhilwara',
#        'Panvel', 'Hyderabad', 'Kota', 'Ghaziabad', 'Chennai', 'Noida',
#        'Kolkata', 'Nagpur', 'Adoni', 'Kanpur', 'Thane', 'Jind', 'Rajkot',
#        'Gangtok', 'Tiruchirappalli', 'Gautam Buddha Nagar', 'Belgaum',
#        'Jaipur', 'Faridabad', 'Bhopal', 'Haridwar', 'Amravati',
#        'Jalandhar', 'Gurgaon', '24 Pargana', 'Kolhapur', 'Patna', 'Surat',
#        'Bagalkot', 'Vapi', 'Navsari', 'Howrah', 'Jammu', 'Palakkad',
#        'Bankura', 'Virar', 'Tirunelveli', 'Durgapur', 'Sonepat',
#        'Chikkaballapur', 'Bulandshahr', 'Marandahalli', 'Ahmedabad',
#        'Chinsurah', 'Secunderabad', 'Ranchi', 'Chandigarh', 'Ludhiana',
#        'Vadodara', 'Balaghat', 'Dehradun', 'Alibag', 'Goa-panaji',
#        'Jhajjar', 'Indore', 'Kanpur Nagar', 'Suri', 'Mangalore', 'Erode',
# ...

# %%
if "Jaipur" in bike['city'].unique():
    print('Present')
else:
    print("Not Present")
# Out:
# Present

# %%
bike
# Out:
#               bike_name     price        city  kms_driven         owner  age  \
# 33         KTM RC 390cc  180000.0        Pune     17700.0   First Owner  4.0
# 35       KTM Duke 200cc   70000.0      Nashik    100000.0  Second Owner  8.0
# 39     KTM RC 200cc ABS  179000.0   Bangalore      3400.0   First Owner  2.0
# 65       KTM Duke 200cc   94700.0    Baripara     32700.0   First Owner  4.0
# 83       KTM Duke 250cc  130000.0  Gandhidham     17500.0  Second Owner  4.0
# ...                 ...       ...         ...         ...           ...  ...
# 32541      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32560      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32579      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32598      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
# 32636      KTM RC 390cc  196700.0      Mumbai     13216.0   First Owner  4.0
#
#        power brand
# 33     390.0   KTM
# ...

# %%
bike['city'].value_counts()
# Out:
# city
# Mumbai          701
# Delhi            65
# Bangalore        49
# Pune             36
# Hyderabad        27
#                ...
# Marandahalli      1
# Chinsurah         1
# Secunderabad      1
# Ranchi            1
# Berhampore        1
# Name: count, Length: 90, dtype: int64

# %%
bike = df[((df['brand'] == "KTM") | (df['brand'] == "Jawa")) & (df['city'] == "Jaipur")]
bike
# Out:
#            bike_name     price    city  kms_driven        owner  age  power  \
# 888     KTM RC 390cc  147000.0  Jaipur     15000.0  First Owner  6.0  390.0
# 4945  KTM Duke 390cc  200000.0  Jaipur     11700.0  First Owner  4.0  390.0
# 4948    KTM RC 390cc  175000.0  Jaipur     10880.0  First Owner  4.0  390.0
# 6073    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6159  KTM Duke 250cc  135000.0  Jaipur     12507.0  First Owner  4.0  250.0
# 6552    KTM RC 200cc  190000.0  Jaipur      7902.0  First Owner  2.0  200.0
# 6734    KTM RC 200cc  128000.0  Jaipur     15000.0  First Owner  4.0  200.0
# 7561  KTM Duke 250cc  150000.0  Jaipur     12500.0  First Owner  4.0  250.0
#
#      brand
# 888    KTM
# 4945   KTM
# 4948   KTM
# 6073   KTM
# 6159   KTM
# 6552   KTM
# 6734   KTM
# 7561   KTM

# %%
# population data ==> df

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
df.shape  # Actual records
# Out:
# (32648, 8)

# %%
df.duplicated().sum()  # duplicates records
# Out:
# 25324

# %%
df.drop_duplicates()
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#             owner  age  power            brand
# ...

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape # All Duplicates are removed
# Out:
# (7324, 8)

# %%
bullet = df[df['brand'] == "Royal Enfield"]

# %%
bullet.shape
# Out:
# (1346, 8)

# %%
bullet.sort_values( by="price")
# Out:
#                                bike_name     price       city  kms_driven  \
# 5811     Royal Enfield Thunderbird 350cc   33500.0      Delhi     49463.0
# 7038  Royal Enfield Bullet Electra 350cc   35000.0      Delhi     60000.0
# 9183     Royal Enfield Thunderbird 350cc   35800.0  Bangalore     90408.0
# 4664  Royal Enfield Bullet Electra 350cc   41000.0      Noida    120000.0
# 5918     Royal Enfield Thunderbird 350cc   45000.0  Bangalore     93108.0
# ...                                  ...       ...        ...         ...
# 5912     Royal Enfield Interceptor 650cc  265500.0    Nellore     12000.0
# 1931     Royal Enfield Interceptor 650cc  270000.0  Ahmedabad      6500.0
# 277      Royal Enfield Interceptor 650cc  280000.0  Bangalore      1500.0
# 2228     Royal Enfield Interceptor 650cc  280000.0     Mumbai      5000.0
# 4912  Royal Enfield Continental GT 650cc  285000.0  Hyderabad      4500.0
#
#                      owner   age  power          brand
# ...

# %%
bullet.sort_values( by="price").head(10)  # ascending order
# Out:
#                                bike_name    price       city  kms_driven  \
# 5811     Royal Enfield Thunderbird 350cc  33500.0      Delhi     49463.0
# 7038  Royal Enfield Bullet Electra 350cc  35000.0      Delhi     60000.0
# 9183     Royal Enfield Thunderbird 350cc  35800.0  Bangalore     90408.0
# 4664  Royal Enfield Bullet Electra 350cc  41000.0      Noida    120000.0
# 5918     Royal Enfield Thunderbird 350cc  45000.0  Bangalore     93108.0
# 2371         Royal Enfield Bullet 350 cc  45000.0    Gurgaon     40000.0
# 8475     Royal Enfield Thunderbird 350cc  45000.0      Delhi     45710.0
# 6489     Royal Enfield Thunderbird 350cc  45918.0  Bangalore     51396.0
# 385      Royal Enfield Thunderbird 350cc  46000.0    Chennai     35000.0
# 9182     Royal Enfield Thunderbird 350cc  47000.0       Pune     60045.0
#
#                      owner   age  power          brand
# 5811           First Owner  16.0  350.0  Royal Enfield
# ...

# %%
bullet.sort_values( by="price" , ascending=False)
# Out:
#                                bike_name     price       city  kms_driven  \
# 4912  Royal Enfield Continental GT 650cc  285000.0  Hyderabad      4500.0
# 2228     Royal Enfield Interceptor 650cc  280000.0     Mumbai      5000.0
# 277      Royal Enfield Interceptor 650cc  280000.0  Bangalore      1500.0
# 1931     Royal Enfield Interceptor 650cc  270000.0  Ahmedabad      6500.0
# 5912     Royal Enfield Interceptor 650cc  265500.0    Nellore     12000.0
# ...                                  ...       ...        ...         ...
# 5918     Royal Enfield Thunderbird 350cc   45000.0  Bangalore     93108.0
# 4664  Royal Enfield Bullet Electra 350cc   41000.0      Noida    120000.0
# 9183     Royal Enfield Thunderbird 350cc   35800.0  Bangalore     90408.0
# 7038  Royal Enfield Bullet Electra 350cc   35000.0      Delhi     60000.0
# 5811     Royal Enfield Thunderbird 350cc   33500.0      Delhi     49463.0
#
#                      owner   age  power          brand
# ...

# %%
bullet.sort_values( by="price" , ascending=False).head(10)
# Out:
#                                bike_name     price         city  kms_driven  \
# 4912  Royal Enfield Continental GT 650cc  285000.0    Hyderabad      4500.0
# 2228     Royal Enfield Interceptor 650cc  280000.0       Mumbai      5000.0
# 277      Royal Enfield Interceptor 650cc  280000.0    Bangalore      1500.0
# 1931     Royal Enfield Interceptor 650cc  270000.0    Ahmedabad      6500.0
# 5912     Royal Enfield Interceptor 650cc  265500.0      Nellore     12000.0
# 1396     Royal Enfield Interceptor 650cc  265000.0        Delhi     11000.0
# 428      Royal Enfield Interceptor 650cc  265000.0    Bangalore     12900.0
# 2332     Royal Enfield Interceptor 650cc  265000.0        Delhi      8500.0
# 81       Royal Enfield Interceptor 650cc  260000.0  Navi Mumbai      3800.0
# 1251     Royal Enfield Interceptor 650cc  250000.0      Silchar       920.0
#
#             owner  age  power          brand
# 4912  First Owner  2.0  650.0  Royal Enfield
# ...

# %%
# find out or filter all the Yamaha brand bike and give top ten lowest kms driven bike of yamaha brand

# %%
bullet = df[df['brand'] == "Yamaha"]
bullet
# Out:
#                                      bike_name     price         city  \
# 4         Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0    Bangalore
# 5                             Yamaha FZs 150cc   53499.0        Delhi
# 10                    Yamaha YZF-R15 2.0 150cc   72000.0    Bangalore
# 11                           Yamaha FZ25 250cc   95000.0    Bangalore
# 24                       Yamaha FZ V 2.0 150cc   45000.0        Delhi
# ...                                        ...       ...          ...
# 9284                         Yamaha FZ25 250cc  115800.0        Delhi
# 9318                        Yamaha Fazer 150cc   37000.0        Delhi
# 9336                       Yamaha YZF-R3 320cc  220000.0        Delhi
# 9342  Yamaha SZ RR V 2.0 150cc Limited Edition   55000.0         Pune
# 9345               Yamaha Fazer FI V 2.0 150cc   78000.0  Kanchipuram
#
#       kms_driven        owner  age  power   brand
# 4        10000.0  First Owner  3.0  150.0  Yamaha
# ...

# %%
bullet.shape
# Out:
# (651, 8)

# %%
bullet.sort_values( by="kms_driven")
# Out:
#                   bike_name     price       city  kms_driven        owner  \
# 628        Yamaha FZs 150cc   77500.0      Delhi        45.0  First Owner
# 2264  Yamaha YZF-R1M 1000cc  600000.0  Faridabad       152.0  First Owner
# 2037  Yamaha YZF-R1M 1000cc  600000.0      Surat       183.0  First Owner
# 8693  Yamaha FZ25 ABS 250cc  142000.0      Delhi       233.0  First Owner
# 4765   Yamaha YZF-R1 1000cc  850000.0   Guwahati       285.0  First Owner
# ...                     ...       ...        ...         ...          ...
# 686       Yamaha FZ16 150cc   28000.0       Kota    100000.0  First Owner
# 57          Yamaha SZ 150cc   25000.0    Vidisha    172082.0  First Owner
# 3482       Yamaha FZs 150cc   65000.0     Mumbai    216000.0  First Owner
# 50          Yamaha FZ 150cc   40000.0     Karnal    357000.0  First Owner
# 7603       Yamaha SZS 150cc   28000.0     Mumbai    566931.0  First Owner
#
#        age   power   brand
# 628    3.0   150.0  Yamaha
# ...

# %%
bullet.sort_values( by="kms_driven" , ascending=True).head(10)
# Out:
#                        bike_name      price       city  kms_driven  \
# 628             Yamaha FZs 150cc    77500.0      Delhi        45.0
# 2264       Yamaha YZF-R1M 1000cc   600000.0  Faridabad       152.0
# 2037       Yamaha YZF-R1M 1000cc   600000.0      Surat       183.0
# 8693       Yamaha FZ25 ABS 250cc   142000.0      Delhi       233.0
# 4765        Yamaha YZF-R1 1000cc   850000.0   Guwahati       285.0
# 4200        Yamaha YZF-R1 1000cc   700000.0      Delhi       285.0
# 123          Yamaha YZF R6 600cc   500000.0  Bangalore       285.0
# 2265  Yamaha RX135 135cc 4-Speed    85000.0     Mumbai       300.0
# 8591        Yamaha YZF-R1 1000cc  1450000.0     Mumbai       340.0
# 5775     Yamaha FZ S V 2.0 150cc    65000.0       Pune       394.0
#
#             owner   age   power   brand
# 628   First Owner   3.0   150.0  Yamaha
# 2264  First Owner   5.0  1000.0  Yamaha
# 2037  First Owner   5.0  1000.0  Yamaha
# 8693  First Owner   2.0   250.0  Yamaha
# ...

# %%
bullet['city'].value_counts().head(20)
# Out:
# city
# Delhi          145
# Bangalore       73
# Mumbai          50
# Faridabad       45
# Pune            36
# Chennai         32
# Gurgaon         29
# Hyderabad       29
# Jaipur          27
# Ghaziabad       14
# Ahmedabad       14
# Noida           11
# Lucknow         10
# Ludhiana         9
# Kanchipuram      7
# Thane            5
# Kolkata          5
# Surat            3
# Chandigarh       3
# Gorakhpur        3
# Name: count, dtype: int64

# %%
jaipur_bullete = bullet[bullet['city'] == 'Jaipur']

# %% [markdown]
# Create new csv file from given data

# %%
jaipur_bullete.to_csv('jaipur_bullete.csv', index = False)   # Export cse file

# %%
jaipur_bullete
# Out:
#                      bike_name     price    city  kms_driven         owner  \
# 972          Yamaha FZ25 250cc  105000.0  Jaipur     10468.0   First Owner
# 1242          Yamaha FZs 150cc   40000.0  Jaipur     34000.0   First Owner
# 1770          Yamaha FZs 150cc   47000.0  Jaipur     18227.0   First Owner
# 2274  Yamaha YZF-R15 2.0 150cc   82800.0  Jaipur      6500.0   First Owner
# 2521        Yamaha Fazer 150cc   34000.0  Jaipur     39000.0   First Owner
# 3874         Yamaha FZ16 150cc   47000.0  Jaipur     18415.0   First Owner
# 4061          Yamaha SZR 150cc   28000.0  Jaipur     20555.0   First Owner
# 4271          Yamaha FZs 150cc   83000.0  Jaipur     14000.0   First Owner
# 4343         Yamaha FZ25 250cc   90000.0  Jaipur     18100.0   First Owner
# 4363          Yamaha SZX 150cc   22500.0  Jaipur     20632.0   First Owner
# 4926          Yamaha FZs 150cc   35000.0  Jaipur     18227.0   First Owner
# ...

# %%
# bike_name , Price ,age , kms_driven
jaipur_bullete[['bike_name' , 'price' ,'age' , 'kms_driven']]
# Out:
#                      bike_name     price   age  kms_driven
# 972          Yamaha FZ25 250cc  105000.0   2.0     10468.0
# 1242          Yamaha FZs 150cc   40000.0  11.0     34000.0
# 1770          Yamaha FZs 150cc   47000.0   6.0     18227.0
# 2274  Yamaha YZF-R15 2.0 150cc   82800.0   3.0      6500.0
# 2521        Yamaha Fazer 150cc   34000.0   9.0     39000.0
# 3874         Yamaha FZ16 150cc   47000.0   8.0     18415.0
# 4061          Yamaha SZR 150cc   28000.0  10.0     20555.0
# 4271          Yamaha FZs 150cc   83000.0   3.0     14000.0
# 4343         Yamaha FZ25 250cc   90000.0   4.0     18100.0
# 4363          Yamaha SZX 150cc   22500.0  11.0     20632.0
# 4926          Yamaha FZs 150cc   35000.0   9.0     18227.0
# 5536          Yamaha SZR 150cc   30000.0   9.0     35600.0
# 6105       Yamaha SS 125 125cc   22000.0  10.0     65798.0
# 6208          Yamaha FZs 150cc   45000.0   7.0     18237.0
# 6210          Yamaha FZs 150cc   44000.0   7.0     32000.0
# ...

# %%
# How to add or delete coloumn in dataframes
# delete column owner

jaipur_bullete.drop('owner',axis='columns')
# Out:
#                      bike_name     price    city  kms_driven   age  power  \
# 972          Yamaha FZ25 250cc  105000.0  Jaipur     10468.0   2.0  250.0
# 1242          Yamaha FZs 150cc   40000.0  Jaipur     34000.0  11.0  150.0
# 1770          Yamaha FZs 150cc   47000.0  Jaipur     18227.0   6.0  150.0
# 2274  Yamaha YZF-R15 2.0 150cc   82800.0  Jaipur      6500.0   3.0  150.0
# 2521        Yamaha Fazer 150cc   34000.0  Jaipur     39000.0   9.0  150.0
# 3874         Yamaha FZ16 150cc   47000.0  Jaipur     18415.0   8.0  150.0
# 4061          Yamaha SZR 150cc   28000.0  Jaipur     20555.0  10.0  150.0
# 4271          Yamaha FZs 150cc   83000.0  Jaipur     14000.0   3.0  150.0
# 4343         Yamaha FZ25 250cc   90000.0  Jaipur     18100.0   4.0  250.0
# 4363          Yamaha SZX 150cc   22500.0  Jaipur     20632.0  11.0  150.0
# 4926          Yamaha FZs 150cc   35000.0  Jaipur     18227.0   9.0  150.0
# 5536          Yamaha SZR 150cc   30000.0  Jaipur     35600.0   9.0  150.0
# ...

# %%
jaipur_bullete.drop('owner',axis=1)


# axis => 1 == Columns
# axis => 0 == Rows
# Out:
#                      bike_name     price    city  kms_driven   age  power  \
# 972          Yamaha FZ25 250cc  105000.0  Jaipur     10468.0   2.0  250.0
# 1242          Yamaha FZs 150cc   40000.0  Jaipur     34000.0  11.0  150.0
# 1770          Yamaha FZs 150cc   47000.0  Jaipur     18227.0   6.0  150.0
# 2274  Yamaha YZF-R15 2.0 150cc   82800.0  Jaipur      6500.0   3.0  150.0
# 2521        Yamaha Fazer 150cc   34000.0  Jaipur     39000.0   9.0  150.0
# 3874         Yamaha FZ16 150cc   47000.0  Jaipur     18415.0   8.0  150.0
# 4061          Yamaha SZR 150cc   28000.0  Jaipur     20555.0  10.0  150.0
# 4271          Yamaha FZs 150cc   83000.0  Jaipur     14000.0   3.0  150.0
# 4343         Yamaha FZ25 250cc   90000.0  Jaipur     18100.0   4.0  250.0
# 4363          Yamaha SZX 150cc   22500.0  Jaipur     20632.0  11.0  150.0
# 4926          Yamaha FZs 150cc   35000.0  Jaipur     18227.0   9.0  150.0
# 5536          Yamaha SZR 150cc   30000.0  Jaipur     35600.0   9.0  150.0
# ...
