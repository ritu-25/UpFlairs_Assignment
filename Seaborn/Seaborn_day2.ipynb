# %% [markdown]
# # Seaborn 24th july

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot  as plt

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # relational plot

# %%
# replot() ==>  relational plot  ==>  for numericals
# catplot ==> categorical plot ==> for  numerical or categorical

# %%
sns.relplot(x='tips',y='total_bill',data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 sns.relplot(x='tips',y='total_bill',data=df)
#       2 plt.show()
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\relational.py:748, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     746         msg = "The `weights` parameter has no effect with kind='scatter'."
#     747         warnings.warn(msg, stacklevel=2)
# --> 748 p = Plotter(
#     749     data=data,
#     750     variables=variables,
#     751     legend=legend,
#     752 )
#     753 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     754 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
sns.relplot(x='tips',y='total_bill',data=df,hue='sex')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 sns.relplot(x='tips',y='total_bill',data=df,hue='sex')
#       2 plt.show()
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\relational.py:748, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     746         msg = "The `weights` parameter has no effect with kind='scatter'."
#     747         warnings.warn(msg, stacklevel=2)
# --> 748 p = Plotter(
#     749     data=data,
#     750     variables=variables,
#     751     legend=legend,
#     752 )
#     753 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     754 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
sns.relplot(x='tips',y='total_bill',data=df,hue='sex',style='smoker')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 sns.relplot(x='tips',y='total_bill',data=df,hue='sex',style='smoker')
#       2 plt.show()
#
# File c:\Program Files\Python312\Lib\site-packages\seaborn\relational.py:748, in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     746         msg = "The `weights` parameter has no effect with kind='scatter'."
#     747         warnings.warn(msg, stacklevel=2)
# --> 748 p = Plotter(
#     749     data=data,
#     750     variables=variables,
#     751     legend=legend,
#     752 )
#     753 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     754 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
sns.relplot(x='tips',y='total_bill',data=df,hue='sex',style='smoker',col='day')
plt.show()

# %%
sns.relplot(x='tips',y='total_bill',data=df,hue='time',col='day')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.relplot(x='tips',y='total_bill',data=df,col='day',kind='line',)
plt.show()

# %% [markdown]
# Relational == > scatter , line

# %%
sns.relplot(x='size',y='total_bill',data=df,col='day',kind='line',)
plt.show()

# %% [markdown]
# # Categorical plot

# %% [markdown]
# Strip chart

# %%
sns.catplot(x='smoker',y='total_bill',data=df)
plt.show()
# Strip chart

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex')
plt.show()

# %% [markdown]
# 'strip', 'swarm', 'box', 'violin', 'boxen', 'point', 'bar', 'count' all form catpot chart

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='swarm')
plt.title('swarm chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='violin')
plt.title('Violin chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='boxen')
plt.title('Boxen chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='bar')
plt.title('Bar chart')
plt.show()

# %%
sns.catplot(x='smoker',y='total_bill',data=df,hue='sex',kind='point')
plt.title('Point chart')
plt.show()

# %%
sns.catplot(x='total_bill',data=df,hue='sex',kind='count')
plt.title('Count chart')
plt.show()

# %% [markdown]
# # use all relational or categorical in the given data sets

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
