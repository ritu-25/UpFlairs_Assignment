# %% [markdown]
# # Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn 
import warnings

# %%
sklearn.__version__
# Out:
# '1.5.0'

# %%
# Row Data
df = pd.read_csv('Used_Bikes.csv')
df
# Out:
#                                   bike_name     price       city  kms_driven  \
# 0        TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1               Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                      Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                      TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4      Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                     ...       ...        ...         ...
# 32643                Hero Passion Pro 100cc   39000.0      Delhi     22000.0
# 32644                  TVS Apache RTR 180cc   30000.0     Karnal      6639.0
# 32645              Bajaj Avenger Street 220   60000.0      Delhi     20373.0
# 32646             Hero Super Splendor 125cc   15600.0     Jaipur     84186.0
# 32647                    Bajaj Pulsar 150cc   22000.0       Pune     60857.0
#
# ...

# %%
df.info() # it defines no. of rows and colouns in a dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32648 entries, 0 to 32647
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bike_name   32648 non-null  object
#  1   price       32648 non-null  float64
#  2   city        32648 non-null  object
#  3   kms_driven  32648 non-null  float64
#  4   owner       32648 non-null  object
#  5   age         32648 non-null  float64
#  6   power       32648 non-null  float64
#  7   brand       32648 non-null  object
# dtypes: float64(4), object(4)
# memory usage: 2.0+ MB

# %%
## for duplicates values
df.duplicated().sum()
# Out:
# 25324

# %%
df.drop_duplicates(inplace=True)
print("Duplicated removed ")
# Out:
# Duplicated removed

# %%
print("duplicated values are removed",df.duplicated().sum())
# Out:
# duplicated values are removed 0

# %%
print("Total no. of bike records",df.shape[0])
# Out:
# Total no. of bike records 7324

# %%
## missing values check in your data
df.isnull().sum()
# Out:
# bike_name     0
# price         0
# city          0
# kms_driven    0
# owner         0
# age           0
# power         0
# brand         0
# dtype: int64

# %%
## there is no alphaetical or numerical error

# %%
df.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#          owner  age  power          brand
# 0  First Owner  3.0  110.0            TVS
# 1  First Owner  4.0  350.0  Royal Enfield
# 2  First Owner  8.0  675.0        Triumph
# 3  First Owner  4.0  180.0            TVS
# 4  First Owner  3.0  150.0         Yamaha

# %%
cat_col =df.select_dtypes(include='O')
cat_col.head()
# Out:
#                               bike_name       city        owner          brand
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad  First Owner            TVS
# 1           Royal Enfield Classic 350cc      Delhi  First Owner  Royal Enfield
# 2                  Triumph Daytona 675R      Delhi  First Owner        Triumph
# 3                  TVS Apache RTR 180cc  Bangalore  First Owner            TVS
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore  First Owner         Yamaha

# %%
cat_col = df.select_dtypes(exclude='O')
cat_col.head()
# Out:
#       price  kms_driven  age  power
# 0   35000.0     17654.0  3.0  110.0
# 1  119900.0     11000.0  4.0  350.0
# 2  600000.0       110.0  8.0  675.0
# 3   65000.0     16329.0  4.0  180.0
# 4   80000.0     10000.0  3.0  150.0

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             6642
# Second Owner             588
# Third Owner               84
# Fourth Owner Or More      10
# Name: count, dtype: int64

# %%
dt = {'First Owner': 1,'Second Owner':2,'Third Owner':3,'Fourth Owner Or More':4}

# %%
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4}

# %%
df['owner'] = df['owner'].map(dt)  # single time execute

# %%
df
# Out:
#                                  bike_name     price       city  kms_driven  \
# 0       TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1              Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                     Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                     TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4     Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
# ...                                    ...       ...        ...         ...
# 9362             Hero Hunk Rear Disc 150cc   25000.0      Delhi     48587.0
# 9369                   Bajaj Avenger 220cc   35000.0  Bangalore     60000.0
# 9370        Harley-Davidson Street 750 ABS  450000.0    Jodhpur      3430.0
# 9371                 Bajaj Dominar 400 ABS  139000.0  Hyderabad     21300.0
# 9372              Bajaj Avenger Street 220   80000.0  Hyderabad      7127.0
#
#       owner  age  power            brand
# ...

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
for i in df['brand'].value_counts():
    if i >= 10:
        print(i)
# Out:
# 2081
# 1346
# 1142
# 676
# 651
# 481
# 375
# 203
# 91
# 61
# 53
# 50
# 46
# 21
# 20
# 10

# %%
# Using query to filter and print counts
counts = df['brand'].value_counts()
print(counts[counts >= 10])
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Name: count, dtype: int64

# %%
bike_brand = list(df['brand'].value_counts().head(16).index)
bike_brand
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW']

# %%
df2 = df[df['brand'].isin(bike_brand)]
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power          brand
# 0      1  3.0  110.0            TVS
# 1      1  4.0  350.0  Royal Enfield
# 2      1  8.0  675.0        Triumph
# 3      1  4.0  180.0            TVS
# 4      1  3.0  150.0         Yamaha

# %%
df['brand'].value_counts()
# Out:
# brand
# Bajaj              2081
# Royal Enfield      1346
# Hero               1142
# Honda               676
# Yamaha              651
# TVS                 481
# KTM                 375
# Suzuki              203
# Harley-Davidson      91
# Kawasaki             61
# Hyosung              53
# Mahindra             50
# Benelli              46
# Triumph              21
# Ducati               20
# BMW                  10
# Jawa                  7
# Indian                3
# MV                    3
# Rajdoot               1
# LML                   1
# Yezdi                 1
# Ideal                 1
# Name: count, dtype: int64

# %%
ls=list(df['brand'].value_counts().keys())
ls
# Out:
# ['Bajaj',
#  'Royal Enfield',
#  'Hero',
#  'Honda',
#  'Yamaha',
#  'TVS',
#  'KTM',
#  'Suzuki',
#  'Harley-Davidson',
#  'Kawasaki',
#  'Hyosung',
#  'Mahindra',
#  'Benelli',
#  'Triumph',
#  'Ducati',
#  'BMW',
#  'Jawa',
#  'Indian',
#  'MV',
#  'Rajdoot',
#  'LML',
#  'Yezdi',
#  'Ideal']

# %%
# for i in range(16):
#     dt[ls[i]]=i

# %%
# dt

# %%
for i in range(len(df2['brand'].value_counts())):
    dt[ls[i]] = i+1

# %%
dt
# Out:
# {'First Owner': 1,
#  'Second Owner': 2,
#  'Third Owner': 3,
#  'Fourth Owner Or More': 4,
#  'Bajaj': 1,
#  'Royal Enfield': 2,
#  'Hero': 3,
#  'Honda': 4,
#  'Yamaha': 5,
#  'TVS': 6,
#  'KTM': 7,
#  'Suzuki': 8,
#  'Harley-Davidson': 9,
#  'Kawasaki': 10,
#  'Hyosung': 11,
#  'Mahindra': 12,
#  'Benelli': 13,
#  'Triumph': 14,
#  'Ducati': 15,
#  'BMW': 16}

# %%
df2['brand'] = df2['brand'].map(dt)
# Out:
# C:\Users\saini\AppData\Local\Temp\ipykernel_13276\3676136198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['brand'] = df2['brand'].map(dt)

# %%
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0      6
# 1      1  4.0  350.0      2
# 2      1  8.0  675.0     14
# 3      1  4.0  180.0      6
# 4      1  3.0  150.0      5

# %%
x = df2.drop('price',axis='columns')   # independents variables 
y = df2[['price']]  # dependent variable or target varible

# %%
x.head()
# Out:
#                               bike_name       city  kms_driven  owner  age  \
# 0    TVS Star City Plus Dual Tone 110cc  Ahmedabad     17654.0      1  3.0
# 1           Royal Enfield Classic 350cc      Delhi     11000.0      1  4.0
# 2                  Triumph Daytona 675R      Delhi       110.0      1  8.0
# 3                  TVS Apache RTR 180cc  Bangalore     16329.0      1  4.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition  Bangalore     10000.0      1  3.0
#
#    power  brand
# 0  110.0      6
# 1  350.0      2
# 2  675.0     14
# 3  180.0      6
# 4  150.0      5

# %%
df2.head()
# Out:
#                               bike_name     price       city  kms_driven  \
# 0    TVS Star City Plus Dual Tone 110cc   35000.0  Ahmedabad     17654.0
# 1           Royal Enfield Classic 350cc  119900.0      Delhi     11000.0
# 2                  Triumph Daytona 675R  600000.0      Delhi       110.0
# 3                  TVS Apache RTR 180cc   65000.0  Bangalore     16329.0
# 4  Yamaha FZ S V 2.0 150cc-Ltd. Edition   80000.0  Bangalore     10000.0
#
#    owner  age  power  brand
# 0      1  3.0  110.0      6
# 1      1  4.0  350.0      2
# 2      1  8.0  675.0     14
# 3      1  4.0  180.0      6
# 4      1  3.0  150.0      5

# %% [markdown]
# # Splitting data dependent and independent

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)  # test size 20%

# %%
# importing linerarregression algorithm class
from sklearn.linear_model import LinearRegression

# %%
# instance creation
lnr = LinearRegression()

# %%
## Algorithm train
lnr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13276\3392018776.py in ?()
#       1 ## Algorithm train
# ----> 2 lnr.fit(x_train,y_train)
#
# c:\Program Files\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py in ?(self, X, y, sample_weight)
#     605         n_jobs_ = self.n_jobs
#     606
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
# ...

# %%
## Model evaluation
print("Training score  ",lnr.score(x_train,y_train) * 100)
print("Testing score  ",lnr.score(x_test,y_test) * 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[364], line 2
#       1 ## Model evaluation
# ----> 2 print("Training score  ",lnr.score(x_train,y_train) * 100)
#       3 print("Testing score  ",lnr.score(x_test,y_test) * 100)
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\base.py:848, in RegressorMixin.score(self, X, y, sample_weight)
#     806 """Return the coefficient of determination of the prediction.
#     807
#     808 The coefficient of determination :math:`R^2` is defined as
#    (...)
#     843 :class:`~sklearn.multioutput.MultiOutputRegressor`).
#     844 """
#     846 from .metrics import r2_score
# --> 848 y_pred = self.predict(X)
#     849 return r2_score(y, y_pred, sample_weight=sample_weight)
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
# ...

# %%
x_test.shape  
# total 1462
# Out:
# (1462, 7)

# %%
### Prediction or testing phase 


# Overfit condition ==>  Trainig - High   and Testing - Low
# Underfit condition ==>  Trainig - Low   and Testing - High
# Generalized condition ==>  if Training is greater then Testing with 5 number


prediction = lnr.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[423], line 3
#       1 ### Prediction or testing phase
# ----> 3 prediction = lnr.predict(x_test)
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# ...

# %%
prediction.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[424], line 1
# ----> 1 prediction.shape
#
# NameError: name 'prediction' is not defined

# %%
comparedf = pd.concat([x_test,y_test],axis=1)

# %%
cpmparedf['prediction'] = prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[428], line 1
# ----> 1 cpmparedf['prediction'] = prediction
#
# NameError: name 'prediction' is not defined

# %%
comparedf.head()
# Out:
#       bike_name  city  kms_driven  owner   age  power  brand     price
# 6593       84.0     4     14547.0      1   3.0  150.0      8   80000.0
# 8201        1.0     6     21000.0      1   8.0  350.0      2   95000.0
# 8505       86.0     4     63000.0      1   9.0  883.0      9  360000.0
# 7960       24.0     9      6859.0      1   3.0  200.0      7  110000.0
# 1121       11.0     4     22840.0      1  11.0  350.0      2   65000.0

# %%
comparedf['residual'] = comparedf['price'] - comparedf['prediction']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prediction'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[512], line 1
# ...

# %%
comparedf.head()
# Out:
#       bike_name  city  kms_driven  owner   age  power  brand     price
# 6593       84.0     4     14547.0      1   3.0  150.0      8   80000.0
# 8201        1.0     6     21000.0      1   8.0  350.0      2   95000.0
# 8505       86.0     4     63000.0      1   9.0  883.0      9  360000.0
# 7960       24.0     9      6859.0      1   3.0  200.0      7  110000.0
# 1121       11.0     4     22840.0      1  11.0  350.0      2   65000.0

# %%
## Prediction for single points
unseen_bike = [[4500,2,3,220,3]]
price_of_unseen_bike = lnr.predict(unseen_bike)
price_of_unseen_bike
# Out:
# c:\Program Files\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[515], line 3
#       1 ## Prediction for single points
#       2 unseen_bike = [[4500,2,3,220,3]]
# ----> 3 price_of_unseen_bike = lnr.predict(unseen_bike)
#       4 price_of_unseen_bike
#
# File c:\Program Files\Python312\Lib\site-packages\sklearn\linear_model\_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# ...

# %%
x_train
# Out:
#                                bike_name       city  kms_driven  owner   age  \
# 3633                  Bajaj Pulsar NS200      Delhi     28000.0      1   9.0
# 2992              Hero Passion Pro 100cc      Delhi     11237.0      1   9.0
# 4736     Hero Passion Pro i3S Disc 100cc      Delhi      4610.0      1   3.0
# 466                  Bajaj Discover 100M  Ahmedabad     33000.0      1   7.0
# 641          Royal Enfield Classic 350cc     Mumbai     20000.0      1   3.0
# ...                                  ...        ...         ...    ...   ...
# 7593                    Honda Livo 110cc  Faridabad     10909.0      1   5.0
# 5485                Honda CBR 150R 150cc      Noida     15000.0      1   5.0
# 5690                Bajaj Discover 125ST      Delhi     45000.0      1   8.0
# 6282  Royal Enfield Bullet Electra 350cc      Delhi     36000.0      3  11.0
# 1610                 Bajaj Avenger 220cc  Bangalore      7600.0      1   6.0
#
#       power  brand
# 3633  200.0      1
# ...

# %% [markdown]
# # Creating folder and its function

# %%
## Saving models 
import os,joblib

# %%
os.makedirs('models',exist_ok=True)

# %%
lnr
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
student_ls = ['mohan','rohan','sohan','manmohan']
student_ls
# Out:
# ['mohan', 'rohan', 'sohan', 'manmohan']

# %%
joblib.dump(student_ls,'studentList.lb')
# Out:
# ['studentList.lb']

# %%
joblib.load('studentList.lb')  # Reading a file from joblib
# Out:
# ['mohan', 'rohan', 'sohan', 'manmohan']

# %%
# Locally added an encrypted file parmanentally
joblib.dump(lnr,'./models/linearRegression.lb')
# Out:
# ['./models/linearRegression.lb']

# %%
joblib.load('./models/linearRegression.lb')
# Out:
# LinearRegression()
